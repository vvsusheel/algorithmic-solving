# %% [markdown]
# <a href="https://colab.research.google.com/github/vvsusheel/algorithmic-solving/blob/master/Assignment0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-contrib-python

# %%
import cv2
import os
from os import path
#IMAGES_FOLDER_PATH = "/content/drive/My Drive/images"
img1 = cv2.imread('/content/drive/My Drive/images/img1.png')
img2 = cv2.imread('/content/drive/My Drive/images/img2.jpg')
img3 = cv2.imread('/content/drive/My Drive/images/img3.jpg')
img4 = cv2.imread('/content/drive/My Drive/images/img4.jpg')

os.chdir('../images')

path1=os.path.join(os.getcwd(),'img1.png')
path2=os.path.join(os.getcwd(),'img2.jpg')
path3=os.path.join(os.getcwd(),'img3.jpg')
path4=os.path.join(os.getcwd(),'img4.jpg')

img1=cv2.imread(path1)
img2=cv2.imread(path2)
img3=cv2.imread(path3)
img4=cv2.imread(path4)
os.chdir('../src')

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig, axs = plt.subplots(2, 2,figsize=(8,8))
axs[0, 0].imshow(img1)
axs[1, 0].imshow(img2)
axs[0, 1].imshow(img3)
axs[1, 1].imshow(img4)

plt.show()

# %%
h, w, c = img1.shape
print("dimension of image 1")
print('width:  ', w)
print('height: ', h)
print('channel:', c)
#print(img2)
# Out:
# dimension of image 1
# width:   960
# height:  984
# channel: 3
# [[[232 237 246]
#   [232 237 246]
#   [232 237 246]
#   ...
#   [232 237 246]
#   [232 237 246]
#   [232 237 246]]
#
#  [[232 237 246]
#   [232 237 246]
#   [232 237 246]
#   ...
#   [232 237 246]
#   [232 237 246]
#   [232 237 246]]
#
#  [[232 237 246]
#   [232 237 246]
#   [232 237 246]
#   ...
#   [232 237 246]
#   [232 237 246]
#   [232 237 246]]
#
#  ...
#
#  [[ 43  41  10]
#   [ 49  51  22]
#   [ 48  54  35]
#   ...
#   [ 82  82  88]
#   [ 65  70  73]
#   [ 77  85  85]]
#
#  [[ 49  47  17]
#   [ 46  46  22]
#   [ 51  58  43]
#   ...
#   [141 141 147]
#   [ 91  95  96]
#   [ 75  81  80]]
#
#  [[ 55  53  23]
#   [ 40  40  16]
#   [ 55  62  47]
#   ...
#   [112 112 118]
#   [101 106 107]
#   [ 98 106 106]]]

# %% [markdown]
# The values are in the range of [0,255]. These numbers in a way indicate the intensity of the colour of the pixel. The coloured images have 3 channels (r,g,b) so in total we can have 255 * 255 * 255 variants of a pixel in a coloured image.
